# %% [markdown]
# Ebru AYDINDAĞ BAYRAK

# %%
#Importing required libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing data

import requests
import io
url="https://raw.githubusercontent.com/globalaihub/introduction-to-machine-learning/5288a74ef63c4b65dbd41db9c32d3e22117f1349/Final%20Project/winequality.csv"
download = requests.get(url).content
df = pd.read_csv(io.StringIO(download.decode('utf-8')))
print (df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
print("Rows, columns: " + str(df.shape)) #Tuple
# Out:
# Rows, columns: (1599, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
#Statistical information of data

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#Missing Values
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Missing (?) Values
df.isin(['?']).sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Correlation of features
corr=df.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
#Correlation Matrix

plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(100, 10, as_cmap=True))

# %%
#Drop duplicates

df.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# 12              5.6             0.615         0.00             1.6      0.089
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Label distribution (countplot)

sns.countplot(x="quality", data=df)

# %%
# Create Classification version of target variable

df['goodquality'] = [1 if x >= 7 else 0 for x in df['quality']]

# Separate feature variables and target variable
X = df.drop(['quality','goodquality'], axis = 1)
y = df['goodquality']

# %%
df['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
#Standardization

from sklearn.preprocessing import StandardScaler
X_features = X
X = StandardScaler().fit_transform(X)

# %%
print("Rows, columns: " + str(df.shape))
# Out:
# Rows, columns: (1599, 13)

# %%
#Splitting  Dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# %%
# ML Application - Decision Tree Algorithm

#Accuracy pf train an test set 
from sklearn.tree import DecisionTreeClassifier

model1 = DecisionTreeClassifier(max_depth=4, random_state=42)
model1.fit(X_train,y_train)
print("Accuracy of train:",model1.score(X_train,y_train))
print("Accuracy of test:",model1.score(X_test,y_test))
# Out:
# Accuracy of train: 0.9151027703306523
# Accuracy of test: 0.8854166666666666

# %%
#Bias for Decision Tree
acc_train=model1.score(X_train,y_train)
bias_train=1-acc_train
bias_train
# Out:
# 0.08489722966934765

# %%
acc_test=model1.score(X_test,y_test)
bias_test=1-acc_test
bias_test
# Out:
# 0.11458333333333337

# %%
# Variance of Decision Tree
var1=bias_test-bias_train
var1
# Out:
# 0.02968610366398572

# %%
#Classification report of Decision Tree

from sklearn.metrics import classification_report
from sklearn import metrics
model1 = DecisionTreeClassifier(random_state=25)
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       416
#            1       0.56      0.70      0.62        64
#
#    micro avg       0.89      0.89      0.89       480
#    macro avg       0.75      0.81      0.78       480
# weighted avg       0.90      0.89      0.89       480

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
print("Precision = {}".format(precision_score(y_test, y_pred1, average='macro')))
print("Recall = {}".format(recall_score(y_test, y_pred1, average='macro')))
print("Accuracy = {}".format(accuracy_score(y_test, y_pred1)))
print("F1 Score = {}".format(f1_score(y_test, y_pred1,average='macro')))
# Out:
# Precision = 0.753968253968254
# Recall = 0.8082932692307692
# Accuracy = 0.8854166666666666
# F1 Score = 0.7766024962978633

# %%
#Accuracy of Decision Tree

print("Accuracy:",metrics.accuracy_score(y_test, y_pred1))
# Out:
# Accuracy: 0.8854166666666666

# %%
#Confusion Matrix of Decision Tree

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred1)
plt.figure(figsize=(10, 7))
ax =sns.heatmap(cm, square=True, annot=True, cbar=True, fmt="d")
ax.set_xlabel('Predicted Quality',fontsize = 15)
ax.set_ylabel('True Quality',fontsize = 15)
plt.show()

# %%
#Random Forest 

#Accuracy of train and test set.
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0)
model2.fit(X_train, y_train)
print("Accuracy of train:",model2.score(X_train,y_train))
print("Accuracy of test:",model2.score(X_test,y_test))
# Out:
# Accuracy of train: 0.9964253798033958
# Accuracy of test: 0.91875

# %%
#Bias for Decision Tree
acc_train=model2.score(X_train,y_train)
bias_train=1-acc_train
bias_train
# Out:
# 0.00357462019660415

# %%
acc_test=model1.score(X_test,y_test)
bias_test=1-acc_test
bias_test
# Out:
# 0.11458333333333337

# %%
#Variance of Decision Tree
var2=bias_test-bias_train
var2
# Out:
# 0.11100871313672922

# %%
#Classification report of Random Forest

from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
model2 = RandomForestClassifier(n_estimators=100, max_depth=10, random_state=0)
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       416
#            1       0.75      0.59      0.66        64
#
#    micro avg       0.92      0.92      0.92       480
#    macro avg       0.84      0.78      0.81       480
# weighted avg       0.91      0.92      0.91       480

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
print("Precision = {}".format(precision_score(y_test, y_pred2, average='macro')))
print("Recall = {}".format(recall_score(y_test, y_pred2, average='macro')))
print("Accuracy = {}".format(accuracy_score(y_test, y_pred2)))
print("F1 Score = {}".format(f1_score(y_test, y_pred1,average='macro')))
# Out:
# Precision = 0.8422459893048129
# Recall = 0.78125
# Accuracy = 0.91875
# F1 Score = 0.7766024962978633

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred2))
# Out:
# Accuracy: 0.91875

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred2)
plt.figure(figsize=(10, 7))
ax =sns.heatmap(cm, square=True, annot=True, cbar=True, fmt="d", cmap="Blues")
ax.set_xlabel('Predicted Quality',fontsize = 15)
ax.set_ylabel('True Quality',fontsize = 15)
plt.show()

# %%
# XGBOOST

import xgboost as xgb
model3 = xgb.XGBClassifier(random_state=1)
model3.fit(X_train, y_train)
y_pred3 = model3.predict(X_test)

#Classification report of Random Forest

print("Accuracy of train:",model2.score(X_train,y_train))
print("Accuracy of test:",model2.score(X_test,y_test))
print(classification_report(y_test, y_pred2))
# Out:
# Accuracy of train: 0.9964253798033958
# Accuracy of test: 0.91875
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95       416
#            1       0.75      0.59      0.66        64
#
#    micro avg       0.92      0.92      0.92       480
#    macro avg       0.84      0.78      0.81       480
# weighted avg       0.91      0.92      0.91       480

# %%
#Bias for XGBoost
acc_train=model3.score(X_train,y_train)
bias_train=1-acc_train
bias_train
# Out:
# 0.04378909740840031

# %%
acc_test=model3.score(X_test,y_test)
bias_test=1-acc_test
bias_test
# Out:
# 0.09791666666666665

# %%
#Variance for XGBoost
var3=bias_test-bias_train
var3
# Out:
# 0.05412756925826634

# %%
from sklearn.metrics import precision_score, recall_score, accuracy_score,f1_score
print("Precision = {}".format(precision_score(y_test, y_pred2, average='macro')))
print("Recall = {}".format(recall_score(y_test, y_pred2, average='macro')))
print("Accuracy = {}".format(accuracy_score(y_test, y_pred2)))
print("F1 Score = {}".format(f1_score(y_test, y_pred1,average='macro')))
# Out:
# Precision = 0.8422459893048129
# Recall = 0.78125
# Accuracy = 0.91875
# F1 Score = 0.7766024962978633

# %%
# Accuracy of XGBoost
print("Accuracy:",metrics.accuracy_score(y_test, y_pred3))
# Out:
# Accuracy: 0.9020833333333333

# %%
# Confusion matrix of XGBoost

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred3)
plt.figure(figsize=(10, 7))
ax =sns.heatmap(cm, square=True, annot=True, cbar=True, fmt="d")
ax.set_xlabel('Predicted Quality',fontsize = 15)
ax.set_ylabel('True Quality',fontsize = 15)
plt.show()

# %%
#Evaluation of Machine Learning Method

print("Accuracy of Decision Tree :",metrics.accuracy_score(y_test, y_pred1))
print("Accuracy of Random Forest :",metrics.accuracy_score(y_test, y_pred2))
print("Accuracy of XGBoost:",metrics.accuracy_score(y_test, y_pred3))
# Out:
# Accuracy of Decision Tree : 0.8854166666666666
# Accuracy of Random Forest : 0.91875
# Accuracy of XGBoost: 0.9020833333333333

# %%
#The best accuracy has been obtained Random Forest algorithm.

# %%
print("F1 Score of Decision Tree = {}".format(f1_score(y_test, y_pred1,average='macro')))
print("F1 Score of Random Forest= {}".format(f1_score(y_test, y_pred2,average='macro')))
print("F1 Score XGBoost = {}".format(f1_score(y_test, y_pred3,average='macro')))
# Out:
# F1 Score of Decision Tree = 0.7766024962978633
# F1 Score of Random Forest= 0.8073578595317725
# F1 Score XGBoost = 0.7678415230254696

# %%
#The best F1_Score has been obtained Random Forest algorithm.
