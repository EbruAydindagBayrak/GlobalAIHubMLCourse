# %%
conda install -c conda-forge scikit-learn
# Out:
# ...
# \
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list scikit-learn
# Out:
# # packages in environment at /Users/ebruaydindagbayrak/anaconda3:
# #
# # Name                    Version                   Build  Channel
# scikit-learn              0.20.3           py37h27c97d8_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda list
# Out:
# # packages in environment at /Users/ebruaydindagbayrak/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2019.10                  py37_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# _py-xgboost-mutex         2.0                       cpu_0    conda-forge
# alabaster                 0.7.12                   py37_0
# anaconda                  custom                   py37_1
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.10.0                   py37_0
# anaconda-project          0.8.2                    py37_0
# appnope                   0.1.0                    py37_0
# appscript                 1.1.0            py37h1de35cc_0
# asn1crypto                0.24.0                   py37_0
# astroid                   2.2.5                    py37_0
# astropy                   3.1.2            py37h1de35cc_0
# atomicwrites              1.3.0                    py37_1
# ...

# %%
import sklearn

# %%
from sklearn.datasets import load_boston
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
Xb, yb=load_boston(return_X_y=True)
df_boston=pd.DataFrame(Xb, columns=load_boston().feature_names)
df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
df_boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# Missing Values 

df_boston.isna().sum()
df_boston.dropna()
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
#Correlation of the features
import seaborn as sns
corr=df_boston.corr() 
print(corr)
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
#Correlation Matrix
plt.figure(figsize=(14, 14))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True, annot = True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
ax.set_ylim(len(corr)+0.5, -0.5);

# %%
# Splitting dataset (0.7 train + 0.3 test)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(Xb, yb, test_size=0.3, random_state=0)

# %%
# Linear Regression

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
modelb = LinearRegression(normalize=False)
modelb.fit(X_train,y_train)

print("Score of the train set",modelb.score(X_train,y_train))
print("Score of the test set",modelb.score(X_test,y_test))
# Out:
# Score of the train set 0.7645451026942549
# Score of the test set 0.6733825506400194

# %%
# Prediction of Linear Regression score

y_train_predict = modelb.predict(X_train)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 4.4674623461466405
# R2 score is 0.7645451026942549

# %%
y_test_predict = modelb.predict(X_test)
rmse = (np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2 = r2_score(y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance for testing set
# --------------------------------------
# RMSE is 5.214975145375406
# R2 score is 0.6733825506400193

# %%
importance = modelb.coef_
for i in range(len(importance)):
    print("Feature", df_boston.columns[i], "Score:", importance[i])
# Out:
# Feature CRIM Score: -0.5558364329805343
# Feature ZN Score: -0.20375764858782652
# Feature INDUS Score: 0.07189094029782894
# Feature CHAS Score: 1.1102230246251565e-15
# Feature NOX Score: -1.319805375665048
# Feature RM Score: 3.817376649035725
# Feature AGE Score: -0.8187837426597442
# Feature DIS Score: -2.179622783383579
# Feature RAD Score: 1.2806559956971977
# Feature TAX Score: -1.6043326668147806
# Feature PTRATIO Score: -1.9134597513799916
# Feature B Score: 0.10653099964205397
# Feature LSTAT Score: -2.1810843519126695

# %%
#Dropping correlated features

new_df = df_boston.drop(["AGE","INDUS"],axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df,yb, test_size=0.3, random_state=42)
modelb = LinearRegression(normalize=False)
modelb.fit(X_train,y_train)
print("Score of the train set",modelb.score(X_train,y_train))
print("Score of the test set",modelb.score(X_test,y_test))
# Out:
# Score of the train set 0.7428288884259309
# Score of the test set 0.7149039348907379

# %%
X_train, X_test, y_train, y_test = train_test_split(new_df,yb, test_size=0.3, random_state=42)
modelb = LinearRegression(normalize=True)
modelb.fit(X_train,y_train)
print("Score of the train set",modelb.score(X_train,y_train))
print("Score of the test set",modelb.score(X_test,y_test))
# Out:
# Score of the train set 0.7428288884259309
# Score of the test set 0.7149039348907364

# %%
#Outlier detection

from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df_boston))
z
# Out:
# array([[0.41978194, 0.28482986, 1.2879095 , ..., 1.45900038, 0.44105193,
#         1.0755623 ],
#        [0.41733926, 0.48772236, 0.59338101, ..., 0.30309415, 0.44105193,
#         0.49243937],
#        [0.41734159, 0.48772236, 0.59338101, ..., 0.30309415, 0.39642699,
#         1.2087274 ],
#        ...,
#        [0.41344658, 0.48772236, 0.11573841, ..., 1.17646583, 0.44105193,
#         0.98304761],
#        [0.40776407, 0.48772236, 0.11573841, ..., 1.17646583, 0.4032249 ,
#         0.86530163],
#        [0.41500016, 0.48772236, 0.11573841, ..., 1.17646583, 0.44105193,
#         0.66905833]])

# %%
len(np.where(z > 3)[0])
# Out:
# 100

# %%
outliers = list(set(np.where(z > 3)[0]))
new_df = df_boston.drop(outliers,axis = 0).reset_index(drop = False)
display(new_df)

y_new = yb[list(new_df["index"])]
len(y_new)
# Out:
#      index      CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD  \
# 0        0   0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0
# 1        1   0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0
# 2        2   0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0
# 3        3   0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0
# 4        4   0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0
# 5        5   0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0
# 6        6   0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0
# 7        7   0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0
# 8        8   0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0
# 9        9   0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0
# 10      10   0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0
# ...

# %%
#Scaling
X_new = new_df.drop('index', axis = 1)

from sklearn.preprocessing import StandardScaler, MinMaxScaler
X_scaled = StandardScaler().fit_transform(X_new)
X_scaled
# Out:
# array([[-0.50009668,  0.42727822, -1.25466328, ..., -1.48379449,
#          0.43991388, -1.1282211 ],
#        [-0.49580542, -0.48858069, -0.55367539, ..., -0.312853  ,
#          0.43991388, -0.48493501],
#        [-0.49580951, -0.48858069, -0.55367539, ..., -0.312853  ,
#          0.36091635, -1.27512537],
#        ...,
#        [-0.4889668 , -0.48858069,  0.16203913, ...,  1.18595212,
#          0.43991388, -1.02616129],
#        [-0.47898384, -0.48858069,  0.16203913, ...,  1.18595212,
#          0.37295037, -0.89626698],
#        [-0.49169611, -0.48858069,  0.16203913, ...,  1.18595212,
#          0.43991388, -0.67977647]])

# %%
#Outlier detection & scaling

X_train, X_test, y_train, y_test = train_test_split(X_scaled,y_new, test_size=0.3, random_state=42)
modelb = LinearRegression(normalize=False)
modelb.fit(X_train,y_train)
print("Score of the train set",modelb.score(X_train,y_train))
print("Score of the test set",modelb.score(X_test,y_test))
# Out:
# Score of the train set 0.7598701100873175
# Score of the test set 0.6739782514175501

# %%
# Lasso Regression- Ridge Regression

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score

# %%
#Scaling 

X_s = preprocessing.scale(X_new)
X_s = pd.DataFrame(X_s, columns = X_new.columns)
X_s
# Out:
#          CRIM        ZN     INDUS  CHAS       NOX        RM       AGE  \
# 0   -0.500097  0.427278 -1.254663   0.0 -0.083120  0.503296 -0.077906
# 1   -0.495805 -0.488581 -0.553675   0.0 -0.708718  0.251194  0.410713
# 2   -0.495810 -0.488581 -0.553675   0.0 -0.708718  1.501880 -0.224135
# 3   -0.494771 -0.488581 -1.273808   0.0 -0.808451  1.195757 -0.769819
# 4   -0.487272 -0.488581 -1.273808   0.0 -0.808451  1.439673 -0.470228
# 5   -0.495286 -0.488581 -1.273808   0.0 -0.808451  0.265928 -0.309732
# 6   -0.483338  0.147432 -0.435862   0.0 -0.210053 -0.418348 -0.027974
# 7   -0.471837  0.147432 -0.435862   0.0 -0.210053 -0.156424  1.024162
# 8   -0.458202  0.147432 -0.435862   0.0 -0.210053 -1.042054  1.163258
# 9   -0.466625  0.147432 -0.435862   0.0 -0.210053 -0.431444  0.660373
# 10  -0.455412  0.147432 -0.435862   0.0 -0.210053  0.179165  0.959964
# 11  -0.477373  0.147432 -0.435862   0.0 -0.210053 -0.423259  0.553376
# ...

# %%
#Lasso Regression

lasso_model = Lasso(alpha = 0.001)
lasso_model.fit(X_train, y_train)
print(f'Lasso model coef: {lasso_model.coef_}')
# Out:
# Lasso model coef: [-0.55069568 -0.20353009  0.06438644  0.         -1.31235011  3.81766142
#  -0.81713869 -2.17534695  1.26383349 -1.59115413 -1.910064    0.10613483
#  -2.18193344]

# %%
lasso_model = Lasso(alpha = 0.002)
lasso_model.fit(X_train, y_train)
print(f'Lasso model coef: {lasso_model.coef_}')
# Out:
# Lasso model coef: [-0.5455205  -0.20333426  0.05691812  0.         -1.30488469  3.81798312
#  -0.81552581 -2.1710355   1.24694344 -1.57794998 -1.90667467  0.10574856
#  -2.18275734]

# %%
lasso_model = Lasso(alpha = 0.003)
lasso_model.fit(X_train, y_train)
print(f'Lasso model coef: {lasso_model.coef_}')
# Out:
# Lasso model coef: [-0.54014835 -0.20327567  0.04958342  0.         -1.29733214  3.81846181
#  -0.81404413 -2.16655919  1.2296638  -1.56458449 -1.90329781  0.10540817
#  -2.18349676]

# %%
lasso_model = Lasso(alpha = 0.004)
lasso_model.fit(X_train, y_train)
print(f'Lasso model coef: {lasso_model.coef_}')
# Out:
# Lasso model coef: [-0.53499665 -0.2031165   0.04212835  0.         -1.28995756  3.81883322
#  -0.81248398 -2.16226765  1.21275977 -1.55132235 -1.89993179  0.10501965
#  -2.18424074]

# %%
lasso_model = Lasso(alpha = 0.005)
lasso_model.fit(X_train, y_train)
print(f'Lasso model coef: {lasso_model.coef_}')
# Out:
# Lasso model coef: [-0.52985228 -0.20296341  0.03467327  0.         -1.28260415  3.81921329
#  -0.81093347 -2.15798327  1.19585621 -1.53804797 -1.89657046  0.10462991
#  -2.18496848]

# %%
#Ridge Regression

ridge_model = Ridge(alpha = 0.02)
ridge_model.fit(X_train, y_train)

print(f'Ridge model coef: {ridge_model.coef_}')
# Out:
# Ridge model coef: [-0.55550179 -0.20387724  0.07141602  0.         -1.31913827  3.81723527
#  -0.81867593 -2.17902341  1.27927348 -1.60316089 -1.91324049  0.10660048
#  -2.18116611]

# %%
ridge_model = Ridge(alpha = 0.01)
ridge_model.fit(X_train, y_train)

print(f'Ridge model coef: {ridge_model.coef_}')
# Out:
# Ridge model coef: [-0.55566903 -0.20381749  0.07165338  0.         -1.31947173  3.81730598
#  -0.81872984 -2.17932303  1.2799644  -1.60374648 -1.9133501   0.10656575
#  -2.18112525]

# %%
ridge_model = Ridge(alpha = 0.03)
ridge_model.fit(X_train, y_train)

print(f'Ridge model coef: {ridge_model.coef_}')
# Out:
# Ridge model coef: [-0.55533472 -0.2039369   0.07117886  0.         -1.31880501  3.8171645
#  -0.818622   -2.17872391  1.27858323 -1.60257592 -1.91313093  0.10663519
#  -2.18120693]

# %%
ridge_model = Ridge(alpha = 0.04)
ridge_model.fit(X_train, y_train)

print(f'Ridge model coef: {ridge_model.coef_}')
# Out:
# Ridge model coef: [-0.55516783 -0.20399646  0.0709419   0.         -1.31847193  3.81709369
#  -0.81856806 -2.17842454  1.27789366 -1.60199155 -1.91302142  0.10666987
#  -2.18124771]

# %%
ridge_model = Ridge(alpha = 0.05)
ridge_model.fit(X_train, y_train)

print(f'Ridge model coef: {ridge_model.coef_}')
# Out:
# Ridge model coef: [-0.55500111 -0.20405593  0.07070514  0.         -1.31813904  3.81702283
#  -0.81851411 -2.1781253   1.27720476 -1.60140778 -1.91291196  0.10670453
#  -2.18128845]

# %%
ridge_model = Ridge(alpha = 10)
ridge_model.fit(X_train, y_train)

print(f'Ridge model coef: {ridge_model.coef_}')
# Out:
# Ridge model coef: [-0.44668178 -0.23266442 -0.09687169  0.         -1.05834518  3.73263167
#  -0.76330474 -1.92956954  0.81553358 -1.21877469 -1.82154609  0.13335524
#  -2.20621079]

# %%
#Evaluation

print("Linear Reg Train: ", regression_model.score(X_train, y_train))
print("Linear Reg Test: ", regression_model.score(X_test, y_test))
print('*************************')
#Lasso
print("Lasso Reg Train: ", lasso_model.score(X_train, y_train))
print("Lasso Reg Test: ", lasso_model.score(X_test, y_test))
print('*************************')
#Ridge
print("Ridge Reg Train: ", ridge_model.score(X_train, y_train))
print("Ridge Reg Test: ", ridge_model.score(X_test, y_test))
# Out:
# Linear Reg Train:  0.7598701100873175
# Linear Reg Test:  0.6739782514175501
# *************************
# Lasso Reg Train:  0.7598484835051629
# Lasso Reg Test:  0.6732715063519636
# *************************
# Ridge Reg Train:  0.7588112820087674
# Ridge Reg Test:  0.6726764430546455

# %%
# The best performing model according to Coefficient of determination (R2) train /test set : Linear Regression
